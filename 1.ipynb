# %%
import os
import sys
import importlib

os.chdir("/Users/mehulpanchal/Development/pythonStudy/multi_agent_code_gen")
sys.path.insert(0, os.getcwd())

import agents.evaluator
importlib.reload(agents.evaluator)

from agents.evaluator import generate_coverage_report_json

# %%
from agents.python_coder import generate_python_code
from agents.test_writer import generate_test_cases
from executor import run_tests
from agents.evaluator import generate_coverage_report_json

def main():
    # Step 1: Generate Python code for the given problem
    problem_description = "Write a Python function to check if string is a palindrome."
    generated_code = generate_python_code(problem_description)
    print("Generated Code:\n", generated_code)

    # Step 2: Generate test cases for the generated code
    test_cases = generate_test_cases(generated_code)
    print("Generated Test Cases:\n", test_cases)

    results = run_tests(generated_code, test_cases)
    print("Execution Results:\n", results)

    # Step 3: Evaluate the generated code using the test cases
    evaluation_result = generate_coverage_report_json(generated_code, test_cases)
    print("Evaluation Result:\n", evaluation_result)

if __name__ == "__main__":
    main()
# Out:
# Generated Code:
#  def is_palindrome(s: str) -> bool:
#     s = ''.join(c for c in s if c.isalnum()).lower()
#     return s == s[::-1]
# Generated Test Cases:
#  import pytest
# from generated_code import is_palindrome
#
# @pytest.fixture
# def setup():
#     pass
#
# @pytest.fixture
# def teardown():
#     pass
#
# def test_is_palindrome_module_docstring():
#     """Test that the is_palindrome function is properly documented."""
#     assert is_palindrome.__doc__ is None
#
# @pytest.mark.parametrize("input_str, expected_output", [
#     ("radar", True),
#     ("level", True),
#     ("madam", True),
#     ("hello", False),
#     ("world", False),
#     ("", True),
#     ("a", True),
# ])
# def test_is_palindrome_positive_scenarios(input_str, expected_output):
#     """Test the is_palindrome function with positive scenarios."""
#     assert is_palindrome(input_str) == expected_output
#
# @pytest.mark.parametrize("input_str, expected_output", [
#     ("A man, a plan, a canal: Panama", True),
#     ("Not a palindrome", False),
#     ("Was it a car or a cat I saw?", True),
#     ("No 'x' in Nixon", True),
#     ("Able was I ere I saw Elba", True),
# ])
# def test_is_palindrome_with_punctuation_and_spaces(input_str, expected_output):
#     """Test the is_palindrome function with punctuation and spaces."""
#     assert is_palindrome(input_str) == expected_output
#
# @pytest.mark.parametrize("input_str, expected_output", [
#     ("12321", True),
#     ("123456", False),
#     ("12321abcba321", False),
#     ("12321 ABCBA 321", False),
# ])
# def test_is_palindrome_with_numbers(input_str, expected_output):
#     """Test the is_palindrome function with numbers."""
#     assert is_palindrome(input_str) == expected_output
#
# def test_is_palindrome_with_non_string_input():
#     """Test the is_palindrome function with non-string input."""
#     with pytest.raises(TypeError):
#         is_palindrome(123)
#
# def test_is_palindrome_with_none_input():
#     """Test the is_palindrome function with None input."""
#     with pytest.raises(TypeError):
#         is_palindrome(None)
#
# def test_is_palindrome_with_empty_string():
#     """Test the is_palindrome function with empty string."""
#     assert is_palindrome("") == True
#
# def test_is_palindrome_with_single_character():
#     """Test the is_palindrome function with single character."""
#     assert is_palindrome("a") == True
# Execution Results:
#  {'success': True, 'stdout': '\x1b============================= test session starts ==============================\x1b\nplatform darwin -- Python 3.12.7, pytest-9.0.2, pluggy-1.6.0\nrootdir: /Users/mehulpanchal/Development/pythonStudy/multi_agent_code_gen/sandbox\nplugins: anyio-4.12.1, repeat-0.9.4, xdist-3.8.0, asyncio-1.3.0, langsmith-0.7.16, deepeval-3.8.9, rerunfailures-16.1\nasyncio: mode=Mode.STRICT, debug=False, asyncio_default_fixture_loop_scope=None, asyncio_default_test_loop_scope=function\ncollected 21 items\n\ntest_generated_code.py \x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b.\x1b\x1b                             [100%]\x1bRunning teardown with pytest sessionfinish\x1b...\x1b\n\n\n\x1b============================== \x1b\x1b21 passed\x1b\x1b in 0.02s\x1b\x1b ==============================\x1b\n', 'stderr': '', 'return_code': 0}
# Evaluation Result:
#  {
#     "overall_coverage_percentage": 95,
#     "total_functions": 1,
#     "tested_functions": 1,
#     "untested_functions": 0,
#     "functions": {
#         "is_palindrome": {
#             "tested": true,
#             "coverage_percentage": 95,
#             "test_cases": 14
#         }
#     },
#     "test_metrics": {
#         "total_tests": 14,
#         "positive_tests": 8,
#         "negative_tests": 4,
#         "edge_case_tests": 4,
#         "error_handling_tests": 2
#     },
#     "coverage_assessment": {
#         "edge_cases": "good",
#         "error_handling": "fair",
#         "parameterization": "good"
#     },
#     "untested_code_paths": [],
#     "missing_test_scenarios": [
#         "Test with extremely long string",
#         "Test with non-ASCII characters",
#         "Test with null bytes in the string"
#     ],
#     "quality_score": 8,
#     "recommendations": [
#         "Add more tests for edge cases",
#         "Improve error handling tests",
#         "Consider using a testing library for more comprehensive testing"
#     ],
#     "risk_assessment": "low"
# }
